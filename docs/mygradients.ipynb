# %%
import sys
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#generate 2D meshgrid
mx, my = (100, 100)
x = np.linspace(0, 10, mx)
y = np.linspace(0, 10, my)
xv, yv = np.meshgrid(x, y)

# %%
# define a function to plot
def f(x, y):
    return x * (y ** 2)

# calculate Z value for each x,y point -> result of function
z = f(xv, yv)

# %%
# make a color plot to display the data
plt.figure(figsize=(14,12))
plt.pcolor(xv, yv, z)
plt.title('2D Color Plot f(x,y) = xy^2')
plt.colorbar();

# %%
# generate 2d meshgrid for the gradient
nx, ny = (10, 10)
x = np.linspace(0, 10, nx)
y = np.linspace(0, 10, ny)
xg, yg = np.meshgrid(x,y)

# calculate the gradient of f(x, y)
Gy, Gx = np.gradient(f(xg,yg)) # numpy deals with rows first (rows = y)

# %%
# make a color plot to display the data
plt.figure(figsize=(14,12))
plt.pcolor(xv,yv,z)
plt.title('Gradient of f(x,y) = xy^2')
plt.colorbar()
plt.quiver(xg, yg, Gx, Gy, scale=1000, color='2');

# %%
# calculate the gradient of f(x,y) = xy^2 manually to check
def ddx(x,y):
    return y**2

def ddy(x,y):
    return 2 * x * y

Gx = ddx(xg, yg)
Gy = ddy(xg, yg)

# %%
# make a color plot to display the data
plt.figure(figsize=(14,12))
plt.pcolor(xv,yv,z)
plt.title('Plot of (y^2, 2xy)')
plt.colorbar()
plt.quiver(xg, yg, Gx, Gy,scale=1000,color='w');
